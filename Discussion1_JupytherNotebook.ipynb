# %% [markdown]
# # The BaBar Experiment: Calculating Center-of-Mass Energy
#
# ### Problem Description
#
# At the **BaBar experiment**, an electron beam ($e^-$) with an energy of **9.0 GeV** was used to collide with a positron beam ($e^+$). The goal was to create a specific particle, the **$\Upsilon(4S)$ meson**, which has a known rest mass of **10.58 GeV**. The challenge is to figure out what energy the positron beam must have to achieve this specific center-of-mass energy.
#
#
#
# ### Your Task
#
# Given a **9.0 GeV electron beam** ($E_1$) and a target $\Upsilon(4S)$ mass of **10.58 GeV** ($E_{CM}$), what should be the energy ($E_2$) of the positron beam in a head-on collision?

# %% [markdown]
# Hints:
# **What is the mass of the electron?**
# **What is the mass of the positron?**
# **What is the formula for center of mass energy for colliding beam experiments?**

# %% [markdown]
# # Your answer:

# %% [markdown]
# # 📘 Markdown + MathJax Cheat Sheet (for Jupyter Markdown cells)
#
# Use these as examples.
#
# ---
#
# ## ✅ Basic Text
# - **Bold** → type `**bold**`
# - *Italic* → type `*italic*`
# - `Inline code` → type `` `code` ``
# - Line break → end a line with **two spaces**
# - Horizontal rule → type `---`
#
# ### Headings
# # H1 (type `# H1`)
# ## H2 (type `## H2`)
# ### H3 (type `### H3`)
#
# ---
#
# ## ✅ Lists
# **Bulleted**
# - Item (type `- Item`)
# - Another item
#   - Sub-item (indent two spaces then `- Sub-item`)
#
# **Numbered**
# 1. First (type `1. First`)
# 2. Second
#    1. Nested (indent three spaces then `1. Nested`)
#
# ---
#
# ## ✅ Links & Images
# - Link: [Example](https://example.com)  ← type `[Example](https://example.com)`
# - Image: ![Alt text](path_or_url.png)  ← type `![Alt text](path_or_url.png)`
#
# ---
#
# ## ✅ Tables
# | Col A | Col B |
# |------:|:-----:|
# |   123 |  abc  |
#
# (To write the table above, type exactly those three lines.)
#
# ---
#
# ## ✅ Math (MathJax)
#
# **Inline math** — wrap in single `$...$`
# Example in a sentence: Einstein’s formula is $E = mc^2$.
#
# **Display math** — wrap in double `$$...$$` on separate lines
# Example:
# $$
# E^2 = p^2 c^2 + m^2 c^4
# $$
#
# **Aligned multi-line equations** (use `aligned` inside `$$...$$`):
# $$
# \begin{aligned}
# E^2 &= p^2 c^2 + m^2 c^4 \\
#     &\xrightarrow{c=1}\; p^2 + m^2
# \end{aligned}
# $$
#
# **Common constructs**
# - Greek letters: $$\alpha,\ \beta,\ \gamma,\ \pi,\ \mu$$
# - Subscripts / superscripts: $$E_{\text{CM}},\ x^2$$
# - Fractions: $$\frac{a}{b}$$
# - Roots: $$\sqrt{p^2 + m^2}$$
# - Vectors / bold: $$\vec{p},\ \mathbf{p}$$
# - Units / text in math: $$\text{GeV},\ \mathrm{m}$$
#
# **Matrices**
# $$
# \begin{pmatrix}
# a & b \\
# c & d
# \end{pmatrix}
# $$
#
# **Equation numbering (optional)**
# $$
# E = mc^2 \tag{1}
# $$
#
# ---
#
# ## ✅ Physics Mini-Examples
#
# **Electron / Positron mass**
# Inline: The electron mass is $m_e \approx 0.511~\text{MeV}/c^2$.
# Display:
# $$
# m_{e^+} = m_e \approx 0.511~\text{MeV}/c^2
# $$
#
# **Energy–momentum relation (natural units)**
# $$
# E^2 = p^2 + m^2
# $$
#
# **Center-of-mass energy (symmetric high-energy collider)**
# $$
# E_{\text{CM}} \approx 2E \quad (\text{for } E_1 = E_2 = E \gg m)
# $$
#
#
# **Breit–Wigner function)**
#
# The Breit–Wigner distribution, used to describe resonances, is
#
# $$
# \sigma(E) = \frac{\Gamma^2 / 4}{(E - E_0)^2 + \Gamma^2 / 4}
# $$
#
# where
# - $E$ is the energy,
# - $E_0$ is the resonance energy (peak position),
# - $\Gamma$ is the decay width of the resonance.
#
#
# ---
#
# ## ✅ Tips & Gotchas
# - Math **won’t render inside** backticked code spans.
# - In normal text, `_` can italicize; inside `$...$` it’s safe for subscripts.
# - If equations don’t render, make sure the cell type is **Markdown** (not Code).
# - To force a line break, end a line with two spaces.
